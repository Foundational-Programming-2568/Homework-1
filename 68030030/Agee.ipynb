// %%
for (int i = 1; i <= 100; i++)
{
    if (i % 2 == 0)
    {
        Console.WriteLine($"{i} เป็นเลขคู่");
    }
    else
    {
        Console.WriteLine($"{i} เป็นเลขคี่");
    }
}
// Out:
// 1 เป็นเลขคี่
// 2 เป็นเลขคู่
// 3 เป็นเลขคี่
// 4 เป็นเลขคู่
// 5 เป็นเลขคี่
// 6 เป็นเลขคู่
// 7 เป็นเลขคี่
// 8 เป็นเลขคู่
// 9 เป็นเลขคี่
// 10 เป็นเลขคู่
// 11 เป็นเลขคี่
// 12 เป็นเลขคู่
// 13 เป็นเลขคี่
// 14 เป็นเลขคู่
// 15 เป็นเลขคี่
// 16 เป็นเลขคู่
// 17 เป็นเลขคี่
// 18 เป็นเลขคู่
// 19 เป็นเลขคี่
// 20 เป็นเลขคู่
// 21 เป็นเลขคี่
// 22 เป็นเลขคู่
// 23 เป็นเลขคี่
// 24 เป็นเลขคู่
// 25 เป็นเลขคี่
// 26 เป็นเลขคู่
// 27 เป็นเลขคี่
// 28 เป็นเลขคู่
// 29 เป็นเลขคี่
// 30 เป็นเลขคู่
// 31 เป็นเลขคี่
// 32 เป็นเลขคู่
// 33 เป็นเลขคี่
// 34 เป็นเลขคู่
// 35 เป็นเลขคี่
// 36 เป็นเลขคู่
// 37 เป็นเลขคี่
// 38 เป็นเลขคู่
// 39 เป็นเลขคี่
// 40 เป็นเลขคู่
// 41 เป็นเลขคี่
// 42 เป็นเลขคู่
// 43 เป็นเลขคี่
// 44 เป็นเลขคู่
// 45 เป็นเลขคี่
// 46 เป็นเลขคู่
// 47 เป็นเลขคี่
// 48 เป็นเลขคู่
// 49 เป็นเลขคี่
// 50 เป็นเลขคู่
// 51 เป็นเลขคี่
// 52 เป็นเลขคู่
// 53 เป็นเลขคี่
// 54 เป็นเลขคู่
// 55 เป็นเลขคี่
// 56 เป็นเลขคู่
// 57 เป็นเลขคี่
// 58 เป็นเลขคู่
// 59 เป็นเลขคี่
// ...

// %%
for (int i = 2; i <= 100; i++)
{
    bool isPrime = true;
    for (int j = 2; j <= Math.Sqrt(i); j++)
    {
        if (i % j == 0)
        {
            isPrime = false;
            break;
        }
    }
    if (isPrime)
    {
        Console.WriteLine($"{i} เป็นจำนวนเฉพาะ");
    }
}
// Out:
// 2 เป็นจำนวนเฉพาะ
// 3 เป็นจำนวนเฉพาะ
// 5 เป็นจำนวนเฉพาะ
// 7 เป็นจำนวนเฉพาะ
// 11 เป็นจำนวนเฉพาะ
// 13 เป็นจำนวนเฉพาะ
// 17 เป็นจำนวนเฉพาะ
// 19 เป็นจำนวนเฉพาะ
// 23 เป็นจำนวนเฉพาะ
// 29 เป็นจำนวนเฉพาะ
// 31 เป็นจำนวนเฉพาะ
// 37 เป็นจำนวนเฉพาะ
// 41 เป็นจำนวนเฉพาะ
// 43 เป็นจำนวนเฉพาะ
// 47 เป็นจำนวนเฉพาะ
// 53 เป็นจำนวนเฉพาะ
// 59 เป็นจำนวนเฉพาะ
// 61 เป็นจำนวนเฉพาะ
// 67 เป็นจำนวนเฉพาะ
// 71 เป็นจำนวนเฉพาะ
// 73 เป็นจำนวนเฉพาะ
// 79 เป็นจำนวนเฉพาะ
// 83 เป็นจำนวนเฉพาะ
// 89 เป็นจำนวนเฉพาะ
// 97 เป็นจำนวนเฉพาะ

// %%
int age = 22;
string category;

if (age >= 1 && age <= 12)
{
    category = "เด็ก";
}
else if (age >= 13 && age <= 19)
{
    category = "วัยรุ่น";
}
else if (age >= 20 && age <= 50)
{
    category = "วัยผู้ใหญ่";
}
else if (age >= 51)
{
    category = "วัยชรา";
}
else
{
    category = "อายุไม่อยู่ในช่วงที่กำหนด";
}

Console.WriteLine($"ผู้ใช้อายุ {age} อยู่ในหมวดหมู่: {category}");
// Out:
// ผู้ใช้อายุ 22 อยู่ในหมวดหมู่: วัยผู้ใหญ่
